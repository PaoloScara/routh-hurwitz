# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd()))

from routh import routh_hurwitz

# Usa normalmente
routh_hurwitz([1, -4, 1, 6])
# Out:
# ...
#   ROUTH-HURWITZ STABILITY TABLE
# ...
#
#   s^3 |   1  1  [+]
#   s^2 |  -4  6  [-]
#   ----+--------
#   s^1 | 5/2  0  [+]
#   s^0 |   6  0  [+]
#
# ...
#   First column: [1, -4, 5/2, 6]
#   Sign changes: 2
# ...
#
#   >> UNSTABLE
#      2 poles in right half-plane
#
# ...
# RouthResult(table=[[1, 1], [-4, 6], [5/2, 0], [6, 0]], degree=3, first_column=[1, -4, 5/2, 6], sign_changes=2, rhp_roots=2, is_stable=False, is_marginally_stable=False, stability_conditions=None, stable_range=None, notes=[], symbolic=False)

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd()))

# Run the examples file with UTF-8 encoding
exec(open('examples.py', encoding='utf-8').read())
# Out:
# ...
#  ROUTH-HURWITZ STABILITY ANALYZER - EXAMPLES
# ...
#
# ────────────────────────────────────────────────────────────────────────────────
# EXAMPLE 1: Unstable System
# ────────────────────────────────────────────────────────────────────────────────
# Polynomial: s³ − 4s² + s + 6 = 0
# Factored: (s+1)(s−2)(s−3) = 0
# Expected: UNSTABLE (2 roots in RHP)
#
# ...
#   ROUTH-HURWITZ STABILITY TABLE
# ...
#
#   s^3 |   1  1  [+]
#   s^2 |  -4  6  [-]
#   ----+--------
#   s^1 | 5/2  0  [+]
#   s^0 |   6  0  [+]
#
# ...
#   First column: [1, -4, 5/2, 6]
#   Sign changes: 2
# ...
#
#   >> UNSTABLE
#      2 poles in right half-plane
#
# ...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# EXAMPLE 2: Stable System
# ────────────────────────────────────────────────────────────────────────────────
# Polynomial: s³ + 3s² + 3s + 1 = 0
# Factored: (s+1)³ = 0
# Expected: STABLE (all roots in LHP)
#
# ...
#   ROUTH-HURWITZ STABILITY TABLE
# ...
#
#   s^3 |   1  3  [+]
#   s^2 |   3  1  [+]
#   ----+--------
# ...

# %%
routh_hurwitz([1, 0, 3, 2])
# Out:
# ...
#   ROUTH-HURWITZ STABILITY TABLE
# ...
#
#   s^3 |       1  3  [+]
#   s^2 |       ε  2  [0]
#   ----+------------
#   s^1 | 3 - 2/ε  0  [-]
#   s^0 |       2  0  [+]
#
# ...
#   First column: [1, ε, 3 - 2/ε, 2]
#   Sign changes: 2
# ...
#
#   >> UNSTABLE
#      2 poles in right half-plane
#
#   Notes:
#   * s^2: zero in first column → ε substitution
#
# ...
# RouthResult(table=[[1, 3], [ε, 2], [(3*ε - 2)/ε, 0], [2, 0]], degree=3, first_column=[1, ε, (3*ε - 2)/ε, 2], sign_changes=2, rhp_roots=2, is_stable=False, is_marginally_stable=False, stability_conditions=None, stable_range=None, notes=['s^2: zero in first column → ε substitution'], symbolic=False)

# %%
# Test veloce - copia questo in una cella del notebook

import sys
sys.path.insert(0, '/content/routh-hurwitz')

# Ricarica il modulo per prendere le modifiche
import importlib
if 'routh' in sys.modules:
    importlib.reload(sys.modules['routh'])

from routh import routh_hurwitz

# Test - ora NON dovrebbe mostrare RouthResult dopo
routh_hurwitz([1, -4, 1, 6])
# Out:
# ...
#   ROUTH-HURWITZ STABILITY TABLE
# ...
#
#   s^3 |   1  1  [+]
#   s^2 |  -4  6  [-]
#   ----+--------
#   s^1 | 5/2  0  [+]
#   s^0 |   6  0  [+]
#
# ...
#   First column: [1, -4, 5/2, 6]
#   Sign changes: 2
# ...
#
#   >> UNSTABLE
#      2 poles in right half-plane
#
# ...
